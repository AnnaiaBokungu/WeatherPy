# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fd9e0d33137204ac915d0da6f647bc64"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fd9e0d33137204ac915d0da6f647bc64

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | oranjemund
# City not found. Skipping...
# Processing Record 2 of Set 1 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | san luis
# Processing Record 6 of Set 1 | saint-pierre
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | mufulira
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | goderich
# Processing Record 19 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | zhezkazgan
# Processing Record 22 of Set 1 | ballina
# Processing Record 23 of Set 1 | glasgow
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | tomari
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | vostok
# Processing Record 34 of Set 1 | saint-leu
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | kununurra
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | kantunilkin
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | merauke
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | saint-francois
# Processing Record 48 of Set 1 | dunedin
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | sao jose da coroa grande
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | kaeo
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | pachino
# Processing Record 7 of Set 2 | inhambane
# Processing Record 8 of Set 2 | assiniboia
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | bilma
# Processing Record 11 of Set 2 | vao
# Processing Record 12 of Set 2 | xuddur
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | xai-xai
# Processing Record 15 of Set 2 | sacama
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | korba
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | miles city
# Processing Record 23 of Set 2 | gulariya
# Processing Record 24 of Set 2 | salisbury
# Processing Record 25 of Set 2 | kroya
# Processing Record 26 of Set 2 | coos bay
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | te anau
# Processing Record 31 of Set 2 | bambanglipuro
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | pervomayskiy
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | mingaora
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | rikitea
# Processing Record 40 of Set 2 | champerico
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 2 | bowling green
# Processing Record 44 of Set 2 | prado
# Processing Record 45 of Set 2 | ukiah
# Processing Record 46 of Set 2 | kieta
# Processing Record 47 of Set 2 | nuuk
# Processing Record 48 of Set 2 | kayerkan
# Processing Record 49 of Set 2 | challans
# Processing Record 50 of Set 2 | hambantota
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | vanimo
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | sterling
# Processing Record 6 of Set 3 | daru
# Processing Record 7 of Set 3 | acapulco
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | hofn
# Processing Record 11 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | carauari
# Processing Record 15 of Set 3 | takoradi
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | falkoping
# City not found. Skipping...
# Processing Record 18 of Set 3 | victor harbor
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | pangnirtung
# Processing Record 21 of Set 3 | korfez
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | bomet
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | zhangjiakou
# Processing Record 27 of Set 3 | portland
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | mount isa
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | qasigiannguit
# Processing Record 33 of Set 3 | itoman
# Processing Record 34 of Set 3 | wajir
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | sembakung
# Processing Record 37 of Set 3 | kattivakkam
# Processing Record 38 of Set 3 | oistins
# Processing Record 39 of Set 3 | carroll
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | sao joao dos patos
# Processing Record 42 of Set 3 | putina
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | moose factory
# Processing Record 45 of Set 3 | denpasar
# Processing Record 46 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 3 | kemijarvi
# Processing Record 48 of Set 3 | kloulklubed
# Processing Record 49 of Set 3 | dingle
# Processing Record 50 of Set 3 | aswan
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | san andres
# Processing Record 4 of Set 4 | rio grande
# Processing Record 5 of Set 4 | kudahuvadhoo
# Processing Record 6 of Set 4 | lucapa
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | brae
# Processing Record 10 of Set 4 | gornopravdinsk
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | sokolo
# Processing Record 13 of Set 4 | vila
# Processing Record 14 of Set 4 | linjiang
# Processing Record 15 of Set 4 | atuona
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | panguipulli
# Processing Record 18 of Set 4 | puerto cabezas
# Processing Record 19 of Set 4 | karratha
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | panlaitan
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | verkhniy uslon
# Processing Record 24 of Set 4 | teguise
# Processing Record 25 of Set 4 | hamilton
# Processing Record 26 of Set 4 | behbahan
# Processing Record 27 of Set 4 | os
# City not found. Skipping...
# Processing Record 28 of Set 4 | madera
# Processing Record 29 of Set 4 | batsfjord
# Processing Record 30 of Set 4 | biak
# Processing Record 31 of Set 4 | smithers
# Processing Record 32 of Set 4 | yerbogachen
# Processing Record 33 of Set 4 | ola
# Processing Record 34 of Set 4 | elvas
# Processing Record 35 of Set 4 | zabid
# Processing Record 36 of Set 4 | aste
# Processing Record 37 of Set 4 | kutum
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | mattru
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | sakakah
# Processing Record 42 of Set 4 | san juan
# Processing Record 43 of Set 4 | nirasaki
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | vredendal
# Processing Record 46 of Set 4 | norman wells
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 4 | port hedland
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | xinqing
# Processing Record 2 of Set 5 | adrar
# Processing Record 3 of Set 5 | puerto maldonado
# Processing Record 4 of Set 5 | barrow
# Processing Record 5 of Set 5 | acarau
# Processing Record 6 of Set 5 | le pradet
# Processing Record 7 of Set 5 | vernashen
# Processing Record 8 of Set 5 | miyang
# Processing Record 9 of Set 5 | usinsk
# Processing Record 10 of Set 5 | cabo san lucas
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | sitka
# Processing Record 13 of Set 5 | kushima
# Processing Record 14 of Set 5 | pervomayskoye
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | rawson
# Processing Record 17 of Set 5 | isangel
# Processing Record 18 of Set 5 | fengzhen
# Processing Record 19 of Set 5 | mahajanga
# Processing Record 20 of Set 5 | karamken
# City not found. Skipping...
# Processing Record 21 of Set 5 | charters towers
# Processing Record 22 of Set 5 | naryan-mar
# Processing Record 23 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 5 | mandalgovi
# Processing Record 25 of Set 5 | hualmay
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | weihai
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | negotino
# Processing Record 30 of Set 5 | riverton
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | sochi
# Processing Record 34 of Set 5 | vaini
# Processing Record 35 of Set 5 | kysyl-syr
# Processing Record 36 of Set 5 | naze
# Processing Record 37 of Set 5 | kupang
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | muttupet
# Processing Record 40 of Set 5 | ancud
# Processing Record 41 of Set 5 | beira
# Processing Record 42 of Set 5 | walvis bay
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | dolo
# Processing Record 45 of Set 5 | byron bay
# Processing Record 46 of Set 5 | eureka
# Processing Record 47 of Set 5 | bredasdorp
# Processing Record 48 of Set 5 | payo
# Processing Record 49 of Set 5 | russell
# Processing Record 50 of Set 5 | buala
# Processing Record 1 of Set 6 | vung tau
# Processing Record 2 of Set 6 | yar-sale
# Processing Record 3 of Set 6 | arraial do cabo
# Processing Record 4 of Set 6 | neiafu
# Processing Record 5 of Set 6 | port hardy
# Processing Record 6 of Set 6 | ostrovnoy
# Processing Record 7 of Set 6 | shihezi
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | mabaruma
# Processing Record 10 of Set 6 | aketi
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | newburgh
# Processing Record 13 of Set 6 | kurchum
# Processing Record 14 of Set 6 | lavumisa
# Processing Record 15 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 6 | jasper
# Processing Record 17 of Set 6 | ikot ekpene
# Processing Record 18 of Set 6 | ixtapa
# Processing Record 19 of Set 6 | kavali
# Processing Record 20 of Set 6 | russelsheim
# Processing Record 21 of Set 6 | anamur
# Processing Record 22 of Set 6 | fallon
# Processing Record 23 of Set 6 | samarai
# Processing Record 24 of Set 6 | a
# City not found. Skipping...
# Processing Record 25 of Set 6 | bonneville
# Processing Record 26 of Set 6 | rorvik
# Processing Record 27 of Set 6 | danilov
# Processing Record 28 of Set 6 | srandakan
# Processing Record 29 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 6 | avera
# Processing Record 31 of Set 6 | shache
# Processing Record 32 of Set 6 | adre
# Processing Record 33 of Set 6 | eskisehir
# Processing Record 34 of Set 6 | zambezi
# Processing Record 35 of Set 6 | ainazi
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | san isidro
# Processing Record 38 of Set 6 | capao da canoa
# Processing Record 39 of Set 6 | sabang
# Processing Record 40 of Set 6 | auki
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | abonnema
# Processing Record 43 of Set 6 | sarkand
# Processing Record 44 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | lundamo
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | kudat
# Processing Record 49 of Set 6 | upernavik
# Processing Record 50 of Set 6 | broome
# Processing Record 1 of Set 7 | nayudupeta
# Processing Record 2 of Set 7 | kivertsi
# Processing Record 3 of Set 7 | hanzhong
# Processing Record 4 of Set 7 | pemangkat
# Processing Record 5 of Set 7 | pavlivka
# Processing Record 6 of Set 7 | shimoda
# Processing Record 7 of Set 7 | vestmannaeyjar
# Processing Record 8 of Set 7 | carahue
# Processing Record 9 of Set 7 | turan
# Processing Record 10 of Set 7 | zachary
# Processing Record 11 of Set 7 | mancio lima
# Processing Record 12 of Set 7 | riyadh
# Processing Record 13 of Set 7 | rujewa
# Processing Record 14 of Set 7 | logumkloster
# Processing Record 15 of Set 7 | manaure
# Processing Record 16 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 7 | la ronge
# Processing Record 18 of Set 7 | sungaipenuh
# Processing Record 19 of Set 7 | senanga
# Processing Record 20 of Set 7 | coquimbo
# Processing Record 21 of Set 7 | paracuru
# Processing Record 22 of Set 7 | cayenne
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | sola
# Processing Record 25 of Set 7 | port shepstone
# Processing Record 26 of Set 7 | banes
# Processing Record 27 of Set 7 | radstadt
# Processing Record 28 of Set 7 | khash
# Processing Record 29 of Set 7 | wasilla
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | santiago del estero
# Processing Record 32 of Set 7 | san patricio
# Processing Record 33 of Set 7 | manokwari
# Processing Record 34 of Set 7 | amapa
# Processing Record 35 of Set 7 | guerrero negro
# Processing Record 36 of Set 7 | antofagasta
# Processing Record 37 of Set 7 | kembe
# Processing Record 38 of Set 7 | nemuro
# Processing Record 39 of Set 7 | bouar
# Processing Record 40 of Set 7 | teya
# Processing Record 41 of Set 7 | nishihara
# Processing Record 42 of Set 7 | puerto del rosario
# Processing Record 43 of Set 7 | harper
# Processing Record 44 of Set 7 | mayskiy
# Processing Record 45 of Set 7 | ilebo
# Processing Record 46 of Set 7 | craig
# Processing Record 47 of Set 7 | cayhagan
# Processing Record 48 of Set 7 | lata
# Processing Record 49 of Set 7 | waipawa
# Processing Record 50 of Set 7 | bougouni
# Processing Record 1 of Set 8 | trincomalee
# Processing Record 2 of Set 8 | ust-maya
# Processing Record 3 of Set 8 | kamenka
# Processing Record 4 of Set 8 | nelson bay
# Processing Record 5 of Set 8 | grand gaube
# Processing Record 6 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | kharar
# Processing Record 8 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 10 of Set 8 | sattankulam
# City not found. Skipping...
# Processing Record 11 of Set 8 | blackfoot
# Processing Record 12 of Set 8 | rubtsovsk
# Processing Record 13 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 8 | okhotsk
# Processing Record 15 of Set 8 | srednyaya yelyuzan
# Processing Record 16 of Set 8 | doljo
# Processing Record 17 of Set 8 | surt
# Processing Record 18 of Set 8 | general roca
# Processing Record 19 of Set 8 | huilong
# Processing Record 20 of Set 8 | hami
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | ambon
# Processing Record 23 of Set 8 | high level
# Processing Record 24 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 25 of Set 8 | huarmey
# Processing Record 26 of Set 8 | hoganas
# Processing Record 27 of Set 8 | ati
# Processing Record 28 of Set 8 | labrea
# Processing Record 29 of Set 8 | olbernhau
# Processing Record 30 of Set 8 | nizamabad
# Processing Record 31 of Set 8 | sovetskiy
# Processing Record 32 of Set 8 | mayo
# Processing Record 33 of Set 8 | ust-nera
# Processing Record 34 of Set 8 | shymkent
# Processing Record 35 of Set 8 | gawler
# Processing Record 36 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 8 | anshun
# Processing Record 38 of Set 8 | sungai siput utara
# City not found. Skipping...
# Processing Record 39 of Set 8 | kuala terengganu
# Processing Record 40 of Set 8 | jacareacanga
# Processing Record 41 of Set 8 | cabra
# Processing Record 42 of Set 8 | taltal
# Processing Record 43 of Set 8 | jardim
# Processing Record 44 of Set 8 | olga
# Processing Record 45 of Set 8 | ugoofaaru
# Processing Record 46 of Set 8 | bulaevo
# Processing Record 47 of Set 8 | sapozhok
# Processing Record 48 of Set 8 | gayeri
# Processing Record 49 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 8 | namatanai
# Processing Record 1 of Set 9 | basco
# Processing Record 2 of Set 9 | ilulissat
# Processing Record 3 of Set 9 | touros
# Processing Record 4 of Set 9 | obidos
# Processing Record 5 of Set 9 | narsaq
# Processing Record 6 of Set 9 | zhetybay
# City not found. Skipping...
# Processing Record 7 of Set 9 | saint-augustin
# Processing Record 8 of Set 9 | chissamba
# Processing Record 9 of Set 9 | hovd
# Processing Record 10 of Set 9 | athabasca
# Processing Record 11 of Set 9 | maningrida
# Processing Record 12 of Set 9 | tessalit
# Processing Record 13 of Set 9 | bhadrachalam
# Processing Record 14 of Set 9 | ngaoundere
# Processing Record 15 of Set 9 | synya
# Processing Record 16 of Set 9 | ozernovskiy
# Processing Record 17 of Set 9 | yumen
# Processing Record 18 of Set 9 | usevya
# Processing Record 19 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 9 | conde
# Processing Record 22 of Set 9 | puerto madryn
# Processing Record 23 of Set 9 | luderitz
# Processing Record 24 of Set 9 | arlit
# Processing Record 25 of Set 9 | aguimes
# Processing Record 26 of Set 9 | prainha
# Processing Record 27 of Set 9 | kijang
# Processing Record 28 of Set 9 | meulaboh
# Processing Record 29 of Set 9 | turukhansk
# Processing Record 30 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 9 | freeport
# Processing Record 32 of Set 9 | namibe
# Processing Record 33 of Set 9 | chittaurgarh
# Processing Record 34 of Set 9 | hasaki
# Processing Record 35 of Set 9 | razumnoye
# Processing Record 36 of Set 9 | ampanihy
# Processing Record 37 of Set 9 | gorontalo
# Processing Record 38 of Set 9 | buraydah
# Processing Record 39 of Set 9 | faya
# Processing Record 40 of Set 9 | roma
# Processing Record 41 of Set 9 | savelugu
# Processing Record 42 of Set 9 | vilyuysk
# Processing Record 43 of Set 9 | aleksandrovka
# Processing Record 44 of Set 9 | esperance
# Processing Record 45 of Set 9 | martapura
# Processing Record 46 of Set 9 | at-bashi
# Processing Record 47 of Set 9 | san luis de palenque
# Processing Record 48 of Set 9 | famoes
# Processing Record 49 of Set 9 | puerto leguizamo
# Processing Record 50 of Set 9 | addi ugri
# City not found. Skipping...
# Processing Record 1 of Set 10 | ambilobe
# Processing Record 2 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 3 of Set 10 | sug-aksy
# City not found. Skipping...
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 10 | gilgit
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 10 | virginia beach
# Processing Record 10 of Set 10 | sikandarabad
# Processing Record 11 of Set 10 | abu kamal
# Processing Record 12 of Set 10 | mezen
# Processing Record 13 of Set 10 | cherskiy
# Processing Record 14 of Set 10 | hurghada
# Processing Record 15 of Set 10 | gbarnga
# Processing Record 16 of Set 10 | lima
# Processing Record 17 of Set 10 | tateyama
# Processing Record 18 of Set 10 | namanga
# Processing Record 19 of Set 10 | loukhi
# Processing Record 20 of Set 10 | southbridge
# Processing Record 21 of Set 10 | la paz
# Processing Record 22 of Set 10 | gaomi
# Processing Record 23 of Set 10 | havoysund
# Processing Record 24 of Set 10 | beringovskiy
# Processing Record 25 of Set 10 | saint anthony
# Processing Record 26 of Set 10 | codrington
# Processing Record 27 of Set 10 | forio
# Processing Record 28 of Set 10 | omsukchan
# Processing Record 29 of Set 10 | manzhouli
# Processing Record 30 of Set 10 | vila franca do campo
# Processing Record 31 of Set 10 | guaruja
# Processing Record 32 of Set 10 | bogolyubovo
# Processing Record 33 of Set 10 | vrede
# Processing Record 34 of Set 10 | iwanai
# Processing Record 35 of Set 10 | obzor
# Processing Record 36 of Set 10 | ponta delgada
# Processing Record 37 of Set 10 | altamira
# Processing Record 38 of Set 10 | qingdao
# Processing Record 39 of Set 10 | krasnogorsk
# Processing Record 40 of Set 10 | inta
# Processing Record 41 of Set 10 | le pont-de-claix
# Processing Record 42 of Set 10 | chicama
# Processing Record 43 of Set 10 | yeppoon
# Processing Record 44 of Set 10 | charlestown
# Processing Record 45 of Set 10 | paranaiba
# Processing Record 46 of Set 10 | katsuura
# Processing Record 47 of Set 10 | chengalpattu
# Processing Record 48 of Set 10 | nalut
# Processing Record 49 of Set 10 | bay roberts
# Processing Record 50 of Set 10 | darhan
# Processing Record 1 of Set 11 | pavlodar
# Processing Record 2 of Set 11 | governador valadares
# Processing Record 3 of Set 11 | mbekenyera
# Processing Record 4 of Set 11 | viedma
# Processing Record 5 of Set 11 | laibin
# Processing Record 6 of Set 11 | mehamn
# Processing Record 7 of Set 11 | cozumel
# Processing Record 8 of Set 11 | labe
# Processing Record 9 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 11 | umm lajj
# Processing Record 11 of Set 11 | tura
# Processing Record 12 of Set 11 | ligayan
# Processing Record 13 of Set 11 | caravelas
# Processing Record 14 of Set 11 | praia
# Processing Record 15 of Set 11 | xapuri
# Processing Record 16 of Set 11 | antalaha
# Processing Record 17 of Set 11 | eenhana
# Processing Record 18 of Set 11 | gondanglegi
# Processing Record 19 of Set 11 | evansville
# Processing Record 20 of Set 11 | fairlie
# Processing Record 21 of Set 11 | palu
# Processing Record 22 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 11 | makakilo city
# Processing Record 24 of Set 11 | tiznit
# Processing Record 25 of Set 11 | tortoli
# Processing Record 26 of Set 11 | udachnyy
# Processing Record 27 of Set 11 | marawi
# Processing Record 28 of Set 11 | marsh harbour
# Processing Record 29 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 11 | broken hill
# Processing Record 31 of Set 11 | klyuchi
# Processing Record 32 of Set 11 | temir
# Processing Record 33 of Set 11 | parnera
# Processing Record 34 of Set 11 | chapais
# Processing Record 35 of Set 11 | villa rica
# Processing Record 36 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 11 | cangzhou
# Processing Record 38 of Set 11 | winona
# Processing Record 39 of Set 11 | coihaique
# Processing Record 40 of Set 11 | sao luiz gonzaga
# Processing Record 41 of Set 11 | bilibino
# Processing Record 42 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 11 | neijiang
# Processing Record 44 of Set 11 | sayyan
# Processing Record 45 of Set 11 | sindal
# Processing Record 46 of Set 11 | salalah
# Processing Record 47 of Set 11 | chardara
# Processing Record 48 of Set 11 | aasiaat
# Processing Record 49 of Set 11 | impfondo
# Processing Record 50 of Set 11 | mookane
# Processing Record 1 of Set 12 | takaka
# Processing Record 2 of Set 12 | nyurba
# Processing Record 3 of Set 12 | aksarka
# Processing Record 4 of Set 12 | calama
# Processing Record 5 of Set 12 | bokhan
# Processing Record 6 of Set 12 | araouane
# Processing Record 7 of Set 12 | fairbanks
# Processing Record 8 of Set 12 | sabha
# Processing Record 9 of Set 12 | komsomolskiy
# Processing Record 10 of Set 12 | westport
# Processing Record 11 of Set 12 | nadym
# Processing Record 12 of Set 12 | aripuana
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | cotonou
# Processing Record 15 of Set 12 | zhigansk
# Processing Record 16 of Set 12 | lasa
# Processing Record 17 of Set 12 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 18 of Set 12 | srednekolymsk
# Processing Record 19 of Set 12 | canaries
# Processing Record 20 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 12 | grindavik
# Processing Record 22 of Set 12 | sioux lookout
# Processing Record 23 of Set 12 | awbari
# Processing Record 24 of Set 12 | husavik
# Processing Record 25 of Set 12 | loa janan
# Processing Record 26 of Set 12 | terrace bay
# Processing Record 27 of Set 12 | srinagar
# Processing Record 28 of Set 12 | aloleng
# Processing Record 29 of Set 12 | bozhou
# Processing Record 30 of Set 12 | alofi
# Processing Record 31 of Set 12 | kargasok
# Processing Record 32 of Set 12 | tilichiki
# Processing Record 33 of Set 12 | bathsheba
# Processing Record 34 of Set 12 | falun
# Processing Record 35 of Set 12 | vilhena
# Processing Record 36 of Set 12 | rocha
# Processing Record 37 of Set 12 | ketchikan
# Processing Record 38 of Set 12 | ahipara
# Processing Record 39 of Set 12 | nordlingen
# City not found. Skipping...
# Processing Record 40 of Set 12 | merced
# Processing Record 41 of Set 12 | bucerias
# Processing Record 42 of Set 12 | muslyumovo
# Processing Record 43 of Set 12 | dawei
# Processing Record 44 of Set 12 | pathein
# Processing Record 45 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 46 of Set 12 | inongo
# Processing Record 47 of Set 12 | natal
# Processing Record 48 of Set 12 | evensk
# Processing Record 49 of Set 12 | digby
# Processing Record 50 of Set 12 | pimenta bueno
# Processing Record 1 of Set 13 | richmond hill
# Processing Record 2 of Set 13 | ayan
# Processing Record 3 of Set 13 | nome
# Processing Record 4 of Set 13 | umm kaddadah
# Processing Record 5 of Set 13 | yenagoa
# Processing Record 6 of Set 13 | casino
# Processing Record 7 of Set 13 | tabuk
# Processing Record 8 of Set 13 | camabatela
# Processing Record 9 of Set 13 | swan hill
# Processing Record 10 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 13 | marzuq
# Processing Record 12 of Set 13 | linxi
# Processing Record 13 of Set 13 | dongsheng
# Processing Record 14 of Set 13 | voi
# Processing Record 15 of Set 13 | hervey bay
# Processing Record 16 of Set 13 | saint charles
# Processing Record 17 of Set 13 | jaramana
# City not found. Skipping...
# Processing Record 18 of Set 13 | rio de janeiro
# Processing Record 19 of Set 13 | poum
# Processing Record 20 of Set 13 | kavieng
# Processing Record 21 of Set 13 | berbera
# Processing Record 22 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 13 | yamoussoukro
# Processing Record 24 of Set 13 | balezino
# Processing Record 25 of Set 13 | mana
# Processing Record 26 of Set 13 | concordia
# Processing Record 27 of Set 13 | felanitx
# Processing Record 28 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 29 of Set 13 | mitu
# Processing Record 30 of Set 13 | miyako
# Processing Record 31 of Set 13 | netanya
# Processing Record 32 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 13 | coihueco
# Processing Record 34 of Set 13 | berlevag
# Processing Record 35 of Set 13 | luwingu
# Processing Record 36 of Set 13 | motozintla
# Processing Record 37 of Set 13 | juruti
# Processing Record 38 of Set 13 | tautira
# Processing Record 39 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | ileza
# Processing Record 41 of Set 13 | pangody
# Processing Record 42 of Set 13 | biskamzha
# Processing Record 43 of Set 13 | thinadhoo
# Processing Record 44 of Set 13 | san carlos de bariloche
# Processing Record 45 of Set 13 | asau
# Processing Record 46 of Set 13 | erzin
# Processing Record 47 of Set 13 | buochs
# Processing Record 48 of Set 13 | shepsi
# Processing Record 49 of Set 13 | kidal
# Processing Record 50 of Set 13 | ginda
# Processing Record 1 of Set 14 | leh
# Processing Record 2 of Set 14 | lookan
# Processing Record 3 of Set 14 | semporna
# Processing Record 4 of Set 14 | kerman
# Processing Record 5 of Set 14 | uspenka
# Processing Record 6 of Set 14 | makat
# Processing Record 7 of Set 14 | honningsvag
# Processing Record 8 of Set 14 | sechura
# Processing Record 9 of Set 14 | puerto escondido
# Processing Record 10 of Set 14 | naraina
# Processing Record 11 of Set 14 | ottumwa
# Processing Record 12 of Set 14 | lebedinyy
# Processing Record 13 of Set 14 | kolobrzeg
# Processing Record 14 of Set 14 | sandpoint
# Processing Record 15 of Set 14 | morro bay
# Processing Record 16 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 14 | beatrice
# Processing Record 18 of Set 14 | statesville
# Processing Record 19 of Set 14 | ust-kut
# Processing Record 20 of Set 14 | camacha
# Processing Record 21 of Set 14 | churapcha
# Processing Record 22 of Set 14 | anakapalle
# Processing Record 23 of Set 14 | port moresby
# Processing Record 24 of Set 14 | tezu
# Processing Record 25 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 14 | pacific grove
# Processing Record 27 of Set 14 | port blair
# Processing Record 28 of Set 14 | odweyne
# Processing Record 29 of Set 14 | igrim
# Processing Record 30 of Set 14 | ca mau
# Processing Record 31 of Set 14 | dire dawa
# Processing Record 32 of Set 14 | bonavista
# Processing Record 33 of Set 14 | taoudenni
# Processing Record 34 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 14 | hohhot
# Processing Record 36 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 14 | granadilla de abona
# Processing Record 38 of Set 14 | rock sound
# Processing Record 39 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 14 | labuhan
# Processing Record 41 of Set 14 | kaka
# Processing Record 42 of Set 14 | kiama
# Processing Record 43 of Set 14 | sinnamary
# Processing Record 44 of Set 14 | kanina
# Processing Record 45 of Set 14 | maniitsoq
# Processing Record 46 of Set 14 | marsa matruh
# Processing Record 47 of Set 14 | guane
# Processing Record 48 of Set 14 | abu samrah
# Processing Record 49 of Set 14 | maragogi
# Processing Record 50 of Set 14 | ferme-neuve
# Processing Record 1 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 15 | malibu
# Processing Record 3 of Set 15 | banjar
# Processing Record 4 of Set 15 | pokhara
# Processing Record 5 of Set 15 | bubaque
# Processing Record 6 of Set 15 | kamaishi
# Processing Record 7 of Set 15 | batagay-alyta
# Processing Record 8 of Set 15 | alekseyevsk
# Processing Record 9 of Set 15 | comodoro rivadavia
# Processing Record 10 of Set 15 | santa maria
# Processing Record 11 of Set 15 | palana
# Processing Record 12 of Set 15 | barretos
# Processing Record 13 of Set 15 | sawai madhopur
# Processing Record 14 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 15 | luena
# Processing Record 16 of Set 15 | redmond
# Processing Record 17 of Set 15 | shingu
# Processing Record 18 of Set 15 | robinson
# Processing Record 19 of Set 15 | chlorakas
# Processing Record 20 of Set 15 | talah
# City not found. Skipping...
# Processing Record 21 of Set 15 | williams lake
# Processing Record 22 of Set 15 | juegang
# Processing Record 23 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 15 | san cristobal
# Processing Record 25 of Set 15 | dalby
# Processing Record 26 of Set 15 | guiratinga
# Processing Record 27 of Set 15 | lakatoro
# Processing Record 28 of Set 15 | villa union
# Processing Record 29 of Set 15 | hayden
# Processing Record 30 of Set 15 | rosetta
# Processing Record 31 of Set 15 | batticaloa
# Processing Record 32 of Set 15 | mbale
# Processing Record 33 of Set 15 | tete
# Processing Record 34 of Set 15 | acambay
# Processing Record 35 of Set 15 | qaqortoq
# Processing Record 36 of Set 15 | kaupanger
# Processing Record 37 of Set 15 | tha maka
# Processing Record 38 of Set 15 | emerald
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
city_data_df = pd.DataFrame (city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany  42.6001  -73.9662     69.46        80          94
# 1          Mataura -46.1927  168.8643     47.48        98         100
# 2         San Luis -33.2950  -66.3356     43.84        89          99
# 3     Saint-Pierre -21.3393   55.4781     69.91        69          20
# 4  Bambous Virieux -20.3428   57.7575     69.22        88          40
# 5          Qaanaaq  77.4840  -69.3632     36.48        94          45
# 6     Ponta Do Sol  32.6667  -17.1000     73.71        74           0
# 7         Mufulira -12.5498   28.2407     50.07        84          16
# 8           Hobart -42.8794  147.3294     53.06        62          93
# 9             Chuy -33.6971  -53.4616     60.30        97         100
#
#    Wind Speed Country                 Date
# 0        1.86      US  2022-07-28 03:50:22
# 1        3.78      NZ  2022-07-28 03:50:40
# 2        7.29      AR  2022-07-28 03:50:41
# 3        5.75      RE  2022-07-28 03:49:17
# 4        6.91      MU  2022-07-28 03:50:41
# 5        2.39      GL  2022-07-28 03:49:31
# 6        5.91      PT  2022-07-28 03:50:42
# 7        3.85      ZM  2022-07-28 03:50:42
# 8        4.00      AU  2022-07-28 03:50:42
# 9        6.91      UY  2022-07-28 03:47:34

# %%
csv_weather_file = "weatherpy_database.csv"
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
